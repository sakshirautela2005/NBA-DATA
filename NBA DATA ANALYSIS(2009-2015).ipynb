# %% [markdown]
# # import python libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # loading data as csv file

# %%
data = pd.read_csv("nba_draft_combine_all_years.csv")

# %%
data.head()
# Out:
#    Unnamed: 0             Player  Year  Draft pick  Height (No Shoes)  \
# 0           0      Blake Griffin  2009         1.0              80.50
# 1           1  Terrence Williams  2009        11.0              77.00
# 2           2   Gerald Henderson  2009        12.0              76.00
# 3           3   Tyler Hansbrough  2009        13.0              80.25
# 4           4         Earl Clark  2009        14.0              80.50
#
#    Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                82.00     83.25           105.0            35.5
# 1                78.25     81.00           103.5            37.0
# 2                77.00     82.25           102.5            35.0
# 3                81.50     83.50           106.0            34.0
# 4                82.25     86.50           109.5            33.0
#
#    Vertical (Max Reach)  Vertical (No Step)  Vertical (No Step Reach)  Weight  \
# ...

# %% [markdown]
# # information related to dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                517 non-null    int64
#  1   Player                    517 non-null    object
#  2   Year                      517 non-null    int64
#  3   Draft pick                384 non-null    float64
#  4   Height (No Shoes)         517 non-null    float64
#  5   Height (With Shoes)       516 non-null    float64
#  6   Wingspan                  517 non-null    float64
#  7   Standing reach            517 non-null    float64
#  8   Vertical (Max)            450 non-null    float64
#  9   Vertical (Max Reach)      450 non-null    float64
#  10  Vertical (No Step)        450 non-null    float64
#  11  Vertical (No Step Reach)  450 non-null    float64
#  12  Weight                    516 non-null    float64
# ...

# %% [markdown]
# # finding the missing value with the help of isnull function

# %%
data.isnull()
# Out:
#      Unnamed: 0  Player   Year  Draft pick  Height (No Shoes)  \
# 0         False   False  False       False              False
# 1         False   False  False       False              False
# 2         False   False  False       False              False
# 3         False   False  False       False              False
# 4         False   False  False       False              False
# ..          ...     ...    ...         ...                ...
# 512       False   False  False        True              False
# 513       False   False  False        True              False
# 514       False   False  False        True              False
# 515       False   False  False        True              False
# 516       False   False  False        True              False
#
#      Height (With Shoes)  Wingspan  Standing reach  Vertical (Max)  \
# 0                  False     False           False           False
# 1                  False     False           False           False
# ...

# %% [markdown]
# # number of missing column

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# Player                        0
# Year                          0
# Draft pick                  133
# Height (No Shoes)             0
# Height (With Shoes)           1
# Wingspan                      0
# Standing reach                0
# Vertical (Max)               67
# Vertical (Max Reach)         67
# Vertical (No Step)           67
# Vertical (No Step Reach)     67
# Weight                        1
# Body Fat                      3
# Hand (Length)                47
# Hand (Width)                 49
# Bench                       233
# Agility                      73
# Sprint                       71
# dtype: int64

# %% [markdown]
# # finding sum of total null values

# %%
data.isnull().sum().sum()
# Out:
# 879

# %% [markdown]
# # shape of data

# %%
data.shape
# Out:
# (517, 19)

# %% [markdown]
# # removing null values

# %%
data.dropna(inplace=True)

# %% [markdown]
# # again checking null values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# Player                      0
# Year                        0
# Draft pick                  0
# Height (No Shoes)           0
# Height (With Shoes)         0
# Wingspan                    0
# Standing reach              0
# Vertical (Max)              0
# Vertical (Max Reach)        0
# Vertical (No Step)          0
# Vertical (No Step Reach)    0
# Weight                      0
# Body Fat                    0
# Hand (Length)               0
# Hand (Width)                0
# Bench                       0
# Agility                     0
# Sprint                      0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # exporting csv file to excel

# %%
data.to_csv("nba_draft_combine_all_years.csv",index=False)
